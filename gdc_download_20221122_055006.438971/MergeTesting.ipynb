# %%
import sys
import re
import fileinput
import pandas as pd 
import os

# %%
# directory name
dirname = '/Users/bigyambat/Documents/GitHub/TRGN510_FinalProject/gdc_download_20221122_055006.438971'
 
# extensions
ext = ('.tsv')

# %%
update_file = pd.read_csv("MANIFEST.txt", sep="\t")

# %%
for files in os.scandir(dirname):
    if files.path.endswith(ext):
        #print(files)  # printing file name
        gene_file = pd.read_csv(files, sep="\t", header=1)
        unstranded_column = gene_file['unstranded']
        concate_file = pd.merge(update_file, unstranded_column, how='outer', on='unstranded_column')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [22], line 6
#       4 gene_file = pd.read_csv(files, sep="\t", header=1)
#       5 unstranded_column = gene_file['unstranded']
# ----> 6 concate_file = pd.merge(update_file, unstranded_column, how='outer', on='unstranded_column')
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/reshape/merge.py:111, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      94 @Substitution("\nleft : DataFrame or named Series")
#      95 @Appender(_merge_doc, indents=0)
#      96 def merge(
#    (...)
#     109     validate: str | None = None,
#     110 ) -> DataFrame:
# --> 111     op = _MergeOperation(
#     112         left,
#     113         right,
#     114         how=how,
#     115         on=on,
#     116         left_on=left_on,
#     117         right_on=right_on,
#     118         left_index=left_index,
#     119         right_index=right_index,
#     120         sort=sort,
#     121         suffixes=suffixes,
#     122         indicator=indicator,
#     123         validate=validate,
#     124     )
#     125     return op.get_result(copy=copy)
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/reshape/merge.py:706, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     699 self._cross = cross_col
#     701 # note this function has side effects
#     702 (
#     703     self.left_join_keys,
#     704     self.right_join_keys,
#     705     self.join_names,
# --> 706 ) = self._get_merge_keys()
#     708 # validate the merge keys dtypes. We may need to coerce
#     709 # to avoid incompatible dtypes
#     710 self._maybe_coerce_merge_keys()
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/reshape/merge.py:1165, in _MergeOperation._get_merge_keys(self)
#    1163 rk = cast(Hashable, rk)
#    1164 if rk is not None:
# -> 1165     right_keys.append(right._get_label_or_level_values(rk))
#    1166 else:
#    1167     # work-around for merge_asof(right_index=True)
#    1168     right_keys.append(right.index)
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/generic.py:1849, in NDFrame._get_label_or_level_values(self, key, axis)
#    1843     values = (
#    1844         self.axes[axis]
#    1845         .get_level_values(key)  # type: ignore[assignment]
#    1846         ._values
#    1847     )
#    1848 else:
# -> 1849     raise KeyError(key)
#    1851 # Check for duplicates
#    1852 if values.ndim > 1:
#
# KeyError: 'unstranded_column'

# %%
concate_file
# Out:
#                                          id  \
# 0      00e68f4b-eec4-45d4-9913-47c76441a0c8
# 1      01b95a3d-3865-4c7f-885b-6b1ae9adaf46
# 2      02f92e01-f0f7-4d23-8044-f86c314594ec
# 3      05b658e2-40cc-4f2b-96c1-9b8ba1c3c723
# 4      067a2ca0-6cef-4075-95aa-fecf3a7b2249
# ...                                     ...
# 60659                                   NaN
# 60660                                   NaN
# 60661                                   NaN
# 60662                                   NaN
# 60663                                   NaN
#
#                                                 filename  \
# 0      00e68f4b-eec4-45d4-9913-47c76441a0c8/b977ab41-...
# 1      01b95a3d-3865-4c7f-885b-6b1ae9adaf46/1314d451-...
# 2      02f92e01-f0f7-4d23-8044-f86c314594ec/52d6634d-...
# 3      05b658e2-40cc-4f2b-96c1-9b8ba1c3c723/0851c935-...
# 4      067a2ca0-6cef-4075-95aa-fecf3a7b2249/fbcab783-...
# ...                                                  ...
# 60659                                                NaN
# 60660                                                NaN
# 60661                                                NaN
# 60662                                                NaN
# 60663                                                NaN
#
#                                     md5       size      state  unstranded
# 0      f650beb6b17cd184787bf902cee07355  4229833.0  validated     2321903
# 1      73d46ea4ded7d80efe4426432188e0f1  4215500.0  validated     5182455
# 2      9951ab06b3dd1f501c2b53e098b01547  4238807.0  validated     4376505
# 3      d603802c821979459b1c1a13df610df2  4213980.0  validated     6427705
# 4      efc22356119d1d8c6ac6014b07dd0a22  4230479.0  validated         249
# ...                                 ...        ...        ...         ...
# 60659                               NaN        NaN        NaN           1
# 60660                               NaN        NaN        NaN         455
# 60661                               NaN        NaN        NaN           0
# 60662                               NaN        NaN        NaN           5
# 60663                               NaN        NaN        NaN          49
#
# [60664 rows x 6 columns]
